# %% [markdown]
# <a href="https://colab.research.google.com/github/akuponiyi/My_NoteBook/blob/main/Omobolanleoluwatayopanda1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
pd.DataFrame({'A': [1,2,3]})
# Out:
#    A
# 0  1
# 1  2
# 2  3
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_3['A'].plot(kind='hist', bins=20, title='A')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['A']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'A'}, axis=1)
#               .sort_values('A', ascending=True))
#   xs = counted['A']
#   ys = counted['counts']
# ...

# %%
d = {"b": 1, "a": 0, "c": 2}
pd.Series(d)
# Out:
# b    1
# a    0
# c    2
# dtype: int64

# %%
d = {"a": 0.0, "b": 1.0, "c": 2.0}
pd.Series(d)
# Out:
# a    0.0
# b    1.0
# c    2.0
# dtype: float64

# %%
pd.Series(d, index=["b", "c", "d", "a"])
# Out:
# b    1.0
# c    2.0
# d    NaN
# a    0.0
# dtype: float64

# %%
pd.Series(10.0, index=["a", "b", "c", "d", "e"])
# Out:
# a    10.0
# b    10.0
# c    10.0
# d    10.0
# e    10.0
# dtype: float64

# %%
index = pd.date_range("1/1/2000", periods=8)

# %%
import numpy as np

# %%
import pandas as pd

# %%
s = pd.Series(np.random.randn(5), index=["a", "b", "c", "d", "e"])
s
# Out:
# a    0.454538
# b   -1.126656
# c    0.981922
# d   -0.097018
# e    1.097084
# dtype: float64

# %%
s = pd.Series(np.random.randn(5), index=["a", "b", "c", "d", "e"])
s.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
d = {"b": 1, "a": 0, "c": 2}
pd.Series(d)
# Out:
# b    1
# a    0
# c    2
# dtype: int64

# %%
s = pd.Series(np.random.randn(5), index=["a", "b", "c", "d", "e"])
s.iloc[0]
s.iloc[[4, 3, 1]]
# Out:
# e    0.216990
# d    0.065000
# b   -0.114894
# dtype: float64

# %%
s = pd.Series(np.random.randn(5), index=["a", "b", "c", "d", "e"])
s.array
# Out:
# <PandasArray>
# [ -0.0331343752145963, -0.05683979943307053,  -0.7291898594025071,
#    0.3907019470956983,   0.9857276145801575]
# Length: 5, dtype: float64

# %%
s = pd.Series(np.random.randn(5), index=["a", "b", "c", "d", "e"])
s.to_numpy()
# Out:
# array([ 0.94258763, -0.68164545,  0.29392232, -0.26551641,  1.68694837])

# %%
s = pd.Series(np.random.randn(5), index=["a", "b", "c", "d", "e"])
s["a"]
# Out:
# -0.462320078077738

# %%
s = pd.Series(np.random.randn(5), index=["a", "b", "c", "d", "e"])
s["e"] = 12.0
s
# Out:
# a     1.789047
# b     1.303198
# c     0.974874
# d     0.706999
# e    12.000000
# dtype: float64

# %%
s = pd.Series(np.random.randn(5), index=["a", "b", "c", "d", "e"])
s["e"] = 12.0
"e" in s
# Out:
# True

# %%
s = pd.Series(np.random.randn(5), index=["a", "b", "c", "d", "e"])
s["e"] = 12.0
s.get("f")
s.get("f", np.nan)
# Out:
# nan

# %%
s = pd.Series(np.random.randn(5), index=["a", "b", "c", "d", "e"])
s * 2
# Out:
# a   -1.645618
# b   -0.523890
# c    1.343640
# d    3.615874
# e    0.787266
# dtype: float64

# %%
s = pd.Series(np.random.randn(5), index=["a", "b", "c", "d", "e"])
np.exp(s)
# Out:
# a    4.021800
# b    1.464786
# c    1.010004
# d    0.309182
# e    1.215309
# dtype: float64

# %%
s = pd.Series(np.random.randn(5), index=["a", "b", "c", "d", "e"])
s.iloc[1:] + s.iloc[:-1]
# Out:
# a         NaN
# b    2.120010
# c    0.049762
# d    0.980643
# e         NaN
# dtype: float64

# %%
s = pd.Series(np.random.randn(5),name="something")
s
# Out:
# 0    0.257175
# 1   -1.315294
# 2    2.270056
# 3    0.010101
# 4   -1.694074
# Name: something, dtype: float64

# %%
s2 = s.rename("different")
s2.name
# Out:
# 'different'

# %%
d = {"one": pd.Series([1.0, 2.0, 3.0], index=["a", "b", "c"]),
    "two": pd.Series([1.0, 2.0, 3.0, 4.0], index=["a", "b", "c", "d"]),}
df = pd.DataFrame(d)
df
# Out:
#    one  two
# a  1.0  1.0
# b  2.0  2.0
# c  3.0  3.0
# d  NaN  4.0

# %%
ser = pd.Series(range(3), index=list("abc"), name="ser")
pd.DataFrame(ser)
# Out:
#    ser
# a    0
# b    1
# c    2

# %%
pd.DataFrame.from_dict(dict([("A", [1, 2, 3]), ("B", [4, 5, 6])]))
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_6['A'].plot(kind='hist', bins=20, title='A')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7['B'].plot(kind='hist', bins=20, title='B')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_8.plot(kind='scatter', x='A', y='B', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# ...

# %%
df ["one"]
# Out:
# a    1.0
# b    2.0
# c    3.0
# d    NaN
# Name: one, dtype: float64

# %%
df["three"] = df ["one"] * df["two"]
df ["flag"] = df["one"] > 2
df
# Out:
#    one  two  three   flag
# a  1.0  1.0    1.0  False
# b  2.0  2.0    4.0  False
# c  3.0  3.0    9.0   True
# d  NaN  4.0    NaN  False

# %%
df["two"] = df ["three"] - df["one"]
df["flag"] = df["three"] < 3
df
# Out:
#    one  two  three   flag
# a  1.0  0.0    1.0   True
# b  2.0  2.0    4.0  False
# c  3.0  6.0    9.0  False
# d  NaN  NaN    NaN  False

# %%
df["two"] = df ["three"] - df["one"]
df["flag"] = df["three"] < 3
df["foo"] = "bar"
df
# Out:
#    one  two  three   flag  foo
# a  1.0  0.0    1.0   True  bar
# b  2.0  2.0    4.0  False  bar
# c  3.0  6.0    9.0  False  bar
# d  NaN  NaN    NaN  False  bar

# %%
df1 = pd.DataFrame({"a": [1, 0, 1], "b": [0, 1, 1]}, dtype=bool)
df2 = pd.DataFrame({"a": [0, 1, 1], "b": [1, 1, 0]}, dtype=bool)
df1 & df2
# Out:
#        a      b
# 0  False  False
# 1  False   True
# 2   True  False

# %%
df1 = pd.DataFrame({"a": [1, 0, 1], "b": [0, 1, 1]}, dtype=bool)
df2 = pd.DataFrame({"a": [0, 1, 1], "b": [1, 1, 0]}, dtype=bool)
df1 ^ df2
# Out:
#        a      b
# 0   True   True
# 1   True  False
# 2  False   True

# %%
# only show the first 5 rows
df[:5].T
# Out:
#           a      b      c      d
# one     1.0    2.0    3.0    NaN
# two     0.0    2.0    6.0    NaN
# three   1.0    4.0    9.0    NaN
# flag   True  False  False  False
# foo     bar    bar    bar    bar

# %%
ser = pd.Series([1, 2, 3, 4])
np.exp(ser)
# Out:
# 0     2.718282
# 1     7.389056
# 2    20.085537
# 3    54.598150
# dtype: float64

# %%
ser = pd.Series([1, 2, 3, 4])
ser1 = pd.Series([1, 2, 3], index=["a", "b", "c"])
ser2 = pd.Series([1, 3, 5], index=["b", "a", "c"])
ser1
# Out:
# a    1
# b    2
# c    3
# dtype: int64
